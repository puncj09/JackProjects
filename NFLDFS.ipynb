# %% [markdown]
# # NFL DFS Lineup Optimizer

# %%
# Store filenames as variables
week = 9
qbFile = "QBWeek9.csv"
rbFile = "RBWeek9.csv"
wrFile = "WRWeek9.csv"
teFile = "TEWeek9.csv"
dFile = "DefWeek9.csv"
dkFile = "DKSalariesWeek9.csv"

# %% [markdown]
# ## Read in DraftKings player pool and salaries

# %%
import csv
import pandas as pd
import re

def load_DK(filename):
    salaries = pd.read_csv(filename)
    salaries = salaries[["Position", "Name", "ID", "Salary", "TeamAbbrev", "Game Info"]]
    
    # Gets opponent and stores in new variable
    game = salaries["Game Info"]
    gameSpl = game.str.split(" ") # splits each string by space
    teams = [] # list of games "CAR@TB"
    for g in range(len(gameSpl)): # loops over each split string and stores first element (game)
        teams.append((gameSpl[g][0]))
        
    df = pd.Series(teams) # convert to series
    df = df.str.split("@") # split teams by '@'
    away = []
    home = []
    for a in range(len(df)):
        away.append((df[a][0]))
        home.append((df[a][1]))
    
    # Add away and home team to "salaries"
    salaries = salaries.assign(Away = away, Home = home)
    salaries.drop(['Game Info'], axis=1, inplace=True) 
    
    #pd.set_option("display.max_rows", None, "display.max_columns", None)
    return(salaries)

# %% [markdown]
# ## Read in FantasyPros projections

# %%
def load_projections(QB, RB, WR, TE, Def):
    # Reads .csv for each position's FP projections (PPR, max/min/median projections)
    QB = pd.read_csv(QB)
    RB = pd.read_csv(RB)
    WR = pd.read_csv(WR)
    TE = pd.read_csv(TE)
    Def = pd.read_csv(Def)
    
    # Removes 2nd row and drops unnecessary columns 
    QB = QB.drop(0)[["Player", "Team", "FPTS"]]
    RB = RB.drop(0)[["Player", "Team", "FPTS"]]
    WR = WR.drop(0)[["Player", "Team", "FPTS"]]
    TE = TE.drop(0)[["Player", "Team", "FPTS"]]
    Def = Def[["Player", "Team", "FPTS"]]
    
    # Adds "Position" column
    QB["Position"] = "QB"
    RB["Position"] = "RB"
    WR["Position"] = "WR"
    TE["Position"] = "TE"
    Def["Position"] = "D/ST"
 
    # Combines all positions into 1 DF
    all_pos = pd.concat([QB, RB, WR, TE, Def], axis=0, ignore_index = True)
    
    # placeholder vectors for floor and ceiling projected points by player
    floor = all_pos["FPTS"][2::3] # gets every 3rd value starting at 3rd row (low)
    ceiling = all_pos["FPTS"][1::3] # gets every 3rd value starting at 2nd row
   
    # gets rid of messy 2nd and 3rd rows for each player (includes every 3rd row, starting with row 1)
    all_pos = all_pos[::3]
    
    # adds floor and ceiling vectors into all_pos DF
    all_pos = all_pos.set_index(floor.index)
    all_pos["Floor"] = floor
    all_pos = all_pos.set_index(ceiling.index)
    all_pos["Ceiling"] = ceiling
    
    # rename "FPTS" to "Median" and Re-order columns
    all_pos = all_pos.rename(columns={"FPTS" : "Median"})
    all_pos = all_pos[["Player", "Team", "Position", "Floor", "Median", "Ceiling"]]
    
    # Reset index of data frame
    all_pos = all_pos.reset_index(drop=True)
    
    # display all players
    pd.set_option("display.max_rows", None, "display.max_columns", None)
    return(all_pos)

# %% [markdown]
# ## Name matching between sites

# %% [markdown]
# The following code creates a function that takes in 2 string vectors (DK Salary names and FP Projections names) and matches them. This finds any tiny differences between the sites naming conventions. For example, Will Fuller and Will Fuller V are the same person. I want to assign an ID to each name so that in the future I can match on ID.

# %%
from fuzzywuzzy import fuzz # import fuzzy string matching library

names_DK = load_DK(dkFile)["Name"]
names_FP = load_projections(qbFile, rbFile, wrFile, teFile, dFile)["Player"]

def name_match(vector1, vector2, ratio=89):
    index = 0
    d = ()
    ell = []
    for a in vector1: 
        for b in vector2:
            if fuzz.ratio(a.lower(), b.lower()) > ratio:
                d = (index, a, b) 
                index += 1
                ell.append((d))
    
    # convert to data frame
    df = pd.DataFrame(ell, columns=["Index", "DK Name", "FP Name"])
    return(df)
    
df_Names = name_match(names_DK, names_FP)
# Out:
# C:\Users\punco\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# ## Merge Salary and FP Projection data on this new Index

# %%
# Add indexes to both data frames
# adding to salary data
new = load_DK(dkFile)
salary_DF = pd.merge(new, df_Names, left_on="Name" , right_on="DK Name")
salary_DF.drop(['DK Name', 'FP Name'], axis=1, inplace=True)

# adding to FP data frame
new2 = load_projections(qbFile, rbFile, wrFile, teFile, dFile)
FP_DF = pd.merge(new2, df_Names, left_on="Player", right_on="FP Name")
FP_DF.drop(['DK Name', 'FP Name'], axis=1, inplace=True)

# Merge salary data with projection data on "Index"
sal_proj = pd.merge(FP_DF, salary_DF, on = ["Index", "Position"])
sal_proj = sal_proj.drop_duplicates(subset=['ID']) # Removes all those Chris Thompson's

# Getting rid of duplicate columns, keeping Draftkings columns "Name" and "TeamAbbrev"
sal_proj.drop(['Player', 'Team'], axis=1, inplace=True)

# Drop low projected players
sal_proj = sal_proj[sal_proj['Ceiling'] >= 5]
print(sal_proj)
# Out:
#     Position  Floor  Median  Ceiling  Index                   Name        ID  \
# 0         QB   21.2    23.7     29.7      3        Patrick Mahomes  15713425
# 1         QB   20.1    23.2     29.6      7         Russell Wilson  15713427
# 2         QB   21.6    23.2     28.9      6           Kyler Murray  15713426
# 3         QB   20.4    22.2     25.6     12         Deshaun Watson  15713428
# 4         QB   20.8    22.1     25.8     14             Josh Allen  15713429
# 5         QB   20.9    22.0     28.7     20         Justin Herbert  15713431
# 6         QB   18.8    20.0     26.9     17          Lamar Jackson  15713430
# 7         QB   16.7    18.4     22.2     30     Ben Roethlisberger  15713433
# 8         QB   17.9    18.4     22.0     31              Matt Ryan  15713434
# 9         QB   16.6    18.0     23.2     26       Matthew Stafford  15713432
# 10        QB   17.2    17.8     23.0     46             Derek Carr  15713439
# 11        QB   16.0    17.6     21.7     34         Ryan Tannehill  15713435
# 12        QB   15.4    16.7     22.9     40      Teddy Bridgewater  15713437
# 13        QB   15.0    16.6     21.7     36           Kirk Cousins  15713436
# 14        QB   15.0    15.6     22.9     56           Daniel Jones  15713443
# 15        QB   15.1    15.0     17.1     61              Drew Lock  15713446
# 16        QB   13.8    14.9     17.3     54             Nick Foles  15713442
# 17        QB   13.5    14.9     20.9     49          Philip Rivers  15713440
# 18        QB   14.1    14.4     17.4     59             Kyle Allen  15713444
# 19        QB   13.8    13.9     16.4     52         Tua Tagovailoa  15713441
# 20        QB   13.9    13.8     16.8     80             Jake Luton  15713450
# 21        QB    5.9     9.9     15.5     89        Garrett Gilbert  15713454
# 22        QB    0.8     6.6     18.5     70       Ryan Fitzpatrick  15713447
# 23        QB    3.4     6.0      6.4     90            Cooper Rush  15734118
# 24        QB    0.6     3.8     12.8    142           Brett Rypien  15713470
# 47        RB   21.1    22.1     24.3      0    Christian McCaffrey  15713483
# 48        RB   15.6    20.6     23.4      2            Dalvin Cook  15713485
# 49        RB   17.3    18.7     20.8      4          Derrick Henry  15713487
# 50        RB   15.8    18.3     20.1     19           James Conner  15713491
# 51        RB   16.4    18.1     19.3     16         James Robinson  15713489
# 52        RB    8.6    16.6     20.8     22          Chase Edmonds  15713493
# 53        RB   13.8    16.6     17.6     32            Josh Jacobs  15713501
# 54        RB   13.7    15.0     18.4     47       David Montgomery  15713513
# 55        RB   13.9    15.0     16.1     38  Clyde Edwards-Helaire  15713505
# 56        RB   12.9    14.9     17.1     35         Todd Gurley II  15713503
# 57        RB   10.0    14.4     16.9     50          David Johnson  15713515
# 58        RB   13.0    13.9     17.0     57      Melvin Gordon III  15713519
# 59        RB    8.3    13.4     17.2     45         Antonio Gibson  15713511
# 60        RB    9.2    13.4     16.3     28        Ezekiel Elliott  15713497
# 61        RB    9.6    13.3     17.9     74         Justin Jackson  15713529
# 62        RB    9.7    13.3     16.7     71          D'Andre Swift  15713527
# 63        RB    9.9    12.2     15.8     41        Jonathan Taylor  15713507
# 64        RB    4.0    12.1     16.2     69          DeeJay Dallas  15713533
# 65        RB    9.0    11.0     15.1     92       Devin Singletary  15713541
# 66        RB    8.1    10.6     12.1     77           J.K. Dobbins  15713535
# 67        RB    7.9     9.6     14.1     60              Zack Moss  15713523
# 68        RB    6.8     9.2     12.5     66           Le'Veon Bell  15713531
# 69        RB    7.2     8.9     10.3    109          J.D. McKissic  15713553
# 70        RB    7.6     8.8     10.0    107           Nyheim Hines  15713551
# 71        RB    5.8     8.6     11.3    103          Joshua Kelley  15713549
# 72        RB    7.0     8.5     10.5     62        Phillip Lindsay  15713521
# 73        RB    2.4     7.5     10.6    153          Jordan Howard  15713645
# 74        RB    4.5     7.4     12.5     84            Gus Edwards  15713539
# 75        RB    6.9     7.2      6.9     83         Mark Ingram II  15713537
# 76        RB    5.0     7.2     12.5     24             Mike Davis  15713495
# 77        RB    4.9     7.0      8.3    173        Adrian Peterson  15713605
# 78        RB    5.4     6.7      7.7    146             Brian Hill  15713657
# 79        RB    3.3     6.0      8.3    191           Tony Pollard  15713571
# 80        RB    3.7     5.9      7.5    169     Alexander Mattison  15713559
# 81        WR    3.7     5.6      7.0    215  Cordarrelle Patterson  15713825
# 83        RB    2.1     5.5      7.7    152          Patrick Laird  15713643
# 84        RB    5.0     5.4      6.1    161         Chris Thompson  15713611
# 85        RB    3.1     5.2      7.5    151           Eno Benjamin  15713637
# 86        RB    4.5     5.2      6.6    112         Jordan Wilkins  15713555
# 87        RB    4.2     4.9      6.1    128          Jalen Richard  15713689
# 88        RB    3.5     4.7      6.3    139           Travis Homer  15713665
# 89        RB    3.6     4.3      5.0    123             Dion Lewis  15713557
# 92        RB    2.0     3.9      5.0    178       Jeremy McNichols  15713575
# 94        RB    2.1     3.7      5.1    174        Kerryon Johnson  15713607
# 95        RB    2.5     3.6      5.1    134        Darrel Williams  15713679
# 96        RB    2.3     3.5      6.9    156           Salvon Ahmed  15713649
# 139       WR   18.4    20.3     23.9      1        DeAndre Hopkins  15713695
# 140       WR   18.6    20.2     22.9     13           Keenan Allen  15713707
# 141       WR   17.6    19.2     22.0     10            Julio Jones  15713701
# 142       WR   16.8    18.8     21.9      8           Stefon Diggs  15713699
# 143       WR   16.5    18.3     21.0     21          Tyler Lockett  15713711
# 144       WR   15.8    17.3     19.9     25           Adam Thielen  15713715
# 145       WR   15.5    17.2     20.5     29         Terry McLaurin  15713719
# 146       WR   13.1    17.0     21.7      5             DK Metcalf  15713697
# 147       WR   14.2    17.0     19.1     11            Tyreek Hill  15713703
# 148       WR   15.8    17.0     20.4     18      Allen Robinson II  15713709
# 149       WR   14.6    16.0     20.6     33         Robby Anderson  15713723
# 150       WR   13.8    15.8     18.9     39       Justin Jefferson  15713727
# 151       WR   11.8    15.0     19.1     23          Will Fuller V  15713713
# 152       WR   11.8    14.9     18.6     27             A.J. Brown  15713717
# 153       WR   11.6    13.8     16.5     63         DeVante Parker  15713745
# 154       WR   11.6    13.8     17.8     67       Marvin Jones Jr.  15713749
# 155       WR   11.7    13.7     17.6     51           Amari Cooper  15713735
# 156       WR   11.5    13.5     18.1     37    JuJu Smith-Schuster  15713725
# 157       WR   11.1    13.5     16.2     65          Mike Williams  15713751
# 158       WR    9.8    13.5     17.4     53          Brandin Cooks  15713739
# 159       WR   11.6    13.0     18.4     72         Darius Slayton  15713753
# 160       WR    7.6    12.7     16.9     48         Chase Claypool  15713733
# 161       WR    8.4    12.3     16.9     58         Christian Kirk  15713743
# 162       WR   11.5    12.1     13.4     87       Sterling Shepard  15713765
# 163       WR   10.2    12.0     13.7     73        Diontae Johnson  15713755
# 164       WR   10.2    11.9     15.4     93            Jerry Jeudy  15713767
# 165       WR    9.6    11.9     12.9     42         Marquise Brown  15713729
# 166       WR    9.3    11.7     13.5     43            Corey Davis  15713731
# 167       WR    9.3    11.6     16.9     95             John Brown  15713775
# 168       WR    9.7    11.4     17.8     15          Calvin Ridley  15713705
# 169       WR   10.5    11.4     11.7     64           DJ Chark Jr.  15713747
# 170       WR    8.8    11.3     12.9     55           Cole Beasley  15713741
# 171       WR    9.6    11.1     15.2     76            Tim Patrick  15713759
# 172       WR   10.0    10.8     12.2    113   Laviska Shenault Jr.  15713785
# 173       WR    8.9    10.8     12.0     81            CeeDee Lamb  15713757
# 174       WR    9.3    10.8     16.7     75        Henry Ruggs III  15713761
# 175       WR    9.1    10.6     11.7    200         Danny Amendola  15713809
# 176       WR    8.5    10.1     11.1    195         Darnell Mooney  15713801
# 177       WR    9.0     9.9     11.2    108            Zach Pascal  15713783
# 178       WR    8.2     9.7     10.6    100           Russell Gage  15713779
# 179       WR    7.8     9.6     10.5    116         Hunter Renfrow  15713789
# 180       WR    8.8     9.4     10.1    185         Anthony Miller  15713795
# 181       WR    6.1     9.3     10.6    104          Curtis Samuel  15713781
# 182       WR    7.8     9.2     10.4     82         Mecole Hardman  15713763
# 183       WR    7.5     9.1     11.0    119       Preston Williams  15713787
# 184       WR    7.4     9.1     10.3    101           Randall Cobb  15713777
# 185       WR   12.3     8.8     12.3     98            T.Y. Hilton  15713773
# 186       WR    6.9     8.4      9.2    193         Michael Gallup  15713797
# 187       WR    7.4     8.1      9.6    194    Michael Pittman Jr.  15713799
# 188       WR    6.2     8.0      9.8     91         Nelson Agholor  15713769
# 189       WR    6.4     7.6      8.4    197       Larry Fitzgerald  15713803
# 190       WR    8.5     7.1      8.5    208        Dontrelle Inman  15713819
# 191       WR    5.4     7.0      8.6    218            David Moore  15713833
# 192       WR    4.3     6.5      7.7    247         Marcus Johnson  15713919
# 193       WR    5.1     6.4      8.2    243           Jakeem Grant  15713931
# 194       WR    4.5     6.4      7.4    209      Demarcus Robinson  15713821
# 195       WR    4.2     6.4      7.5    206              KJ Hamler  15713815
# 196       WR    5.0     6.0      7.3    217           Jalen Guyton  15713835
# 197       WR    2.3     6.0      8.5    198            Marvin Hall  15713805
# 198       WR    4.3     5.9      6.8    259          Isaiah Wright  15713859
# 199       WR    3.4     5.8      9.8    213          Andy Isabella  15713823
# 200       WR    3.2     5.7     12.0    238      Olamide Zaccheaus  15713947
# 201       WR    3.0     5.5      7.3    268       James Washington  15713839
# 202       WR    4.6     5.4      6.0    214           Miles Boykin  15713829
# 203       WR    3.8     5.3      6.4    121        Willie Snead IV  15713791
# 204       WR    4.1     5.3      6.4    265          Kalif Raymond  15713849
# 205       WR    4.1     5.3      6.1    252           Kenny Stills  15713901
# 206       WR    4.7     5.3      6.3    250           Chris Conley  15713895
# 207       WR    5.3     5.1      5.3    240            Isaiah Ford  15713837
# 208       WR    3.1     4.6      6.2    212       DaeSean Hamilton  15713831
# 209       WR    3.2     4.6      5.7    210          Gabriel Davis  15713827
# 210       WR    2.7     4.5      5.5    245         Devin Duvernay  15713909
# 211       WR    2.6     4.2      5.4    203          Bryan Edwards  15713813
# 212       WR    2.4     4.1      5.6    258         Quintez Cephus  15713893
# 216       WR    2.5     3.7      5.9    224          Tyron Johnson  15713985
# 252       TE   15.1    17.2     19.7      9           Travis Kelce  15713993
# 253       TE   14.6    16.3     19.7     44          Darren Waller  15713995
# 254       TE   12.1    13.0     16.1     68         T.J. Hockenson  15713997
# 255       TE   10.4    12.0     15.7     85           Mark Andrews  15713999
# 256       TE   10.6    11.9     14.8     97              Noah Fant  15714001
# 257       TE    8.2    11.4     15.1    131           Hunter Henry  15714013
# 258       TE    8.3    10.2     11.5    118           Hayden Hurst  15714011
# 259       TE    9.2     9.9     11.0    110            Evan Engram  15714007
# 260       TE    8.1     9.9     12.5    196            Jonnu Smith  15714015
# 261       TE    8.3     9.8     11.4    102             Eric Ebron  15714003
# 262       TE    7.6     8.9      9.8    199           Jimmy Graham  15714017
# 263       TE    8.0     8.8     10.6    105           Mike Gesicki  15714005
# 264       TE    7.3     8.5     13.9    204            Trey Burton  15714023
# 265       TE    7.1     8.3      9.8    201           Logan Thomas  15714019
# 266       TE    6.6     7.4      8.0    202         Dalton Schultz  15714021
# 267       TE    6.0     6.5      7.5    219             Greg Olsen  15714031
# 268       TE    5.3     6.4      7.9    277     Albert Okwuegbunam  15714047
# 269       TE    5.6     6.4      7.2    207           Jordan Akins  15714027
# 270       TE    5.4     6.0      6.9    278        Anthony Firkser  15714049
# 271       TE    4.1     5.6      6.8    275          Irv Smith Jr.  15714041
# 272       TE    4.4     5.6      6.6    280           Tyler Eifert  15714051
# 273       TE    4.1     5.5      7.4    273             Jack Doyle  15714037
# 274       TE    4.3     5.3      7.0    114           Darren Fells  15714009
# 275       TE    3.9     5.0      5.4    220           Kyle Rudolph  15714033
# 276       TE    3.6     4.9      5.8    249            Mo Alie-Cox  15714035
# 277       TE    3.6     4.3      5.2    205            Dawson Knox  15714025
# 279       TE    3.5     4.3      5.4    272             Dan Arnold  15714043
# 280       TE    5.4     3.9      5.4    297              Jake Butt  15714133
# 283       TE    2.4     3.8      5.9    298           Nick Vannett  15714135
# 289       TE    2.4     3.1      5.2    305           Adam Shaheen  15714129
#
#      Salary TeamAbbrev Away Home
# 0      8100         KC  CAR   KC
# 1      7600        SEA  SEA  BUF
# 2      7800        ARI  MIA  ARI
# 3      7100        HOU  HOU  JAX
# 4      7000        BUF  SEA  BUF
# 5      6800        LAC   LV  LAC
# 6      6900        BAL  BAL  IND
# 7      6500        PIT  PIT  DAL
# 8      6400        ATL  DEN  ATL
# 9      6600        DET  DET  MIN
# 10     5700         LV   LV  LAC
# 11     6300        TEN  CHI  TEN
# 12     6000        CAR  CAR   KC
# 13     6200        MIN  DET  MIN
# 14     5400        NYG  NYG  WAS
# 15     5200        DEN  DEN  ATL
# 16     5500        CHI  CHI  TEN
# 17     5600        IND  BAL  IND
# 18     5300        WAS  NYG  WAS
# 19     5500        MIA  MIA  ARI
# 20     4900        JAX  HOU  JAX
# 21     4800        DAL  PIT  DAL
# 22     5000        MIA  MIA  ARI
# 23     4800        DAL  PIT  DAL
# 24     4000        DEN  DEN  ATL
# 47     8500        CAR  CAR   KC
# 48     8200        MIN  DET  MIN
# 49     7900        TEN  CHI  TEN
# 50     6900        PIT  PIT  DAL
# 51     7000        JAX  HOU  JAX
# 52     6800        ARI  MIA  ARI
# 53     6300         LV   LV  LAC
# 54     5700        CHI  CHI  TEN
# 55     6100         KC  CAR   KC
# 56     6200        ATL  DEN  ATL
# 57     5600        HOU  HOU  JAX
# 58     5300        DEN  DEN  ATL
# 59     5800        WAS  NYG  WAS
# 60     6600        DAL  PIT  DAL
# 61     4900        LAC   LV  LAC
# 62     5000        DET  DET  MIN
# 63     6000        IND  BAL  IND
# 64     5000        SEA  SEA  BUF
# 65     4700        BUF  SEA  BUF
# 66     4900        BAL  BAL  IND
# 67     5200        BUF  SEA  BUF
# 68     5100         KC  CAR   KC
# 69     4300        WAS  NYG  WAS
# 70     4400        IND  BAL  IND
# 71     4400        LAC   LV  LAC
# 72     5200        DEN  DEN  ATL
# 73     4000        MIA  MIA  ARI
# 74     4800        BAL  BAL  IND
# 75     4800        BAL  BAL  IND
# 76     6700        CAR  CAR   KC
# 77     4000        DET  DET  MIN
# 78     4000        ATL  DEN  ATL
# 79     4000        DAL  PIT  DAL
# 80     4000        MIN  DET  MIN
# 81     3200        CHI  CHI  TEN
# 83     4000        MIA  MIA  ARI
# 84     4000        JAX  HOU  JAX
# 85     4000        ARI  MIA  ARI
# 86     4200        IND  BAL  IND
# 87     4000         LV   LV  LAC
# 88     4000        SEA  SEA  BUF
# 89     4100        NYG  NYG  WAS
# 92     4000        TEN  CHI  TEN
# 94     4000        DET  DET  MIN
# 95     4000         KC  CAR   KC
# 96     4000        MIA  MIA  ARI
# 139    8200        ARI  MIA  ARI
# 140    7000        LAC   LV  LAC
# 141    7200        ATL  DEN  ATL
# 142    7400        BUF  SEA  BUF
# 143    6800        SEA  SEA  BUF
# 144    6700        MIN  DET  MIN
# 145    6500        WAS  NYG  WAS
# 146    7800        SEA  SEA  BUF
# 147    7100         KC  CAR   KC
# 148    6900        CHI  CHI  TEN
# 149    6300        CAR  CAR   KC
# 150    6100        MIN  DET  MIN
# 151    6800        HOU  HOU  JAX
# 152    6600        TEN  CHI  TEN
# 153    5200        MIA  MIA  ARI
# 154    5100        DET  DET  MIN
# 155    5600        DAL  PIT  DAL
# 156    6200        PIT  PIT  DAL
# 157    5100        LAC   LV  LAC
# 158    5500        HOU  HOU  JAX
# 159    5000        NYG  NYG  WAS
# 160    5700        PIT  PIT  DAL
# 161    5300        ARI  MIA  ARI
# 162    4800        NYG  NYG  WAS
# 163    5000        PIT  PIT  DAL
# 164    4700        DEN  DEN  ATL
# 165    6000        BAL  BAL  IND
# 166    5900        TEN  CHI  TEN
# 167    4600        BUF  SEA  BUF
# 168    7000        ATL  DEN  ATL
# 169    5200        JAX  HOU  JAX
# 170    5400        BUF  SEA  BUF
# 171    4900        DEN  DEN  ATL
# 172    4200        JAX  HOU  JAX
# 173    4900        DAL  PIT  DAL
# 174    4900         LV   LV  LAC
# 175    3700        DET  DET  MIN
# 176    3900        CHI  CHI  TEN
# 177    4300        IND  BAL  IND
# 178    4500        ATL  DEN  ATL
# 179    4100         LV   LV  LAC
# 180    4000        CHI  CHI  TEN
# 181    4400        CAR  CAR   KC
# 182    4800         KC  CAR   KC
# 183    4100        MIA  MIA  ARI
# 184    4500        HOU  HOU  JAX
# 185    4600        IND  BAL  IND
# 186    4000        DAL  PIT  DAL
# 187    3900        IND  BAL  IND
# 188    4700         LV   LV  LAC
# 189    3800        ARI  MIA  ARI
# 190    3300        WAS  NYG  WAS
# 191    3100        SEA  SEA  BUF
# 192    3000        IND  BAL  IND
# 193    3000        MIA  MIA  ARI
# 194    3200         KC  CAR   KC
# 195    3400        DEN  DEN  ATL
# 196    3100        LAC   LV  LAC
# 197    3800        DET  DET  MIN
# 198    3000        WAS  NYG  WAS
# 199    3200        ARI  MIA  ARI
# 200    3000        ATL  DEN  ATL
# 201    3000        PIT  PIT  DAL
# 202    3200        BAL  BAL  IND
# 203    4100        BAL  BAL  IND
# 204    3000        TEN  CHI  TEN
# 205    3000        HOU  HOU  JAX
# 206    3000        JAX  HOU  JAX
# 207    3000        MIA  MIA  ARI
# 208    3200        DEN  DEN  ATL
# 209    3200        BUF  SEA  BUF
# 210    3000        BAL  BAL  IND
# 211    3500         LV   LV  LAC
# 212    3000        DET  DET  MIN
# 216    3000        LAC   LV  LAC
# 252    7200         KC  CAR   KC
# 253    5800         LV   LV  LAC
# 254    5100        DET  DET  MIN
# 255    4800        BAL  BAL  IND
# 256    4600        DEN  DEN  ATL
# 257    4000        LAC   LV  LAC
# 258    4100        ATL  DEN  ATL
# 259    4300        NYG  NYG  WAS
# 260    3900        TEN  CHI  TEN
# 261    4500        PIT  PIT  DAL
# 262    3800        CHI  CHI  TEN
# 263    4400        MIA  MIA  ARI
# 264    3500        IND  BAL  IND
# 265    3700        WAS  NYG  WAS
# 266    3600        DAL  PIT  DAL
# 267    3100        SEA  SEA  BUF
# 268    2800        DEN  DEN  ATL
# 269    3300        HOU  HOU  JAX
# 270    2800        TEN  CHI  TEN
# 271    2900        MIN  DET  MIN
# 272    2700        JAX  HOU  JAX
# 273    2900        IND  BAL  IND
# 274    4200        HOU  HOU  JAX
# 275    3100        MIN  DET  MIN
# 276    3000        IND  BAL  IND
# 277    3400        BUF  SEA  BUF
# 279    2900        ARI  MIA  ARI
# 280    2500        DEN  DEN  ATL
# 283    2500        DEN  DEN  ATL
# 289    2500        MIA  MIA  ARI

# %%
def df_stuff(df):
    df = df[df["Salary"] > 7000]
    print(df)

df_stuff(sal_proj)
# Out:
#     Position  Floor  Median  Ceiling  Index                 Name        ID  \
# 0         QB   21.2    23.7     29.7      3      Patrick Mahomes  15713425
# 1         QB   20.1    23.2     29.6      7       Russell Wilson  15713427
# 2         QB   21.6    23.2     28.9      6         Kyler Murray  15713426
# 3         QB   20.4    22.2     25.6     12       Deshaun Watson  15713428
# 47        RB   21.1    22.1     24.3      0  Christian McCaffrey  15713483
# 48        RB   15.6    20.6     23.4      2          Dalvin Cook  15713485
# 49        RB   17.3    18.7     20.8      4        Derrick Henry  15713487
# 139       WR   18.4    20.3     23.9      1      DeAndre Hopkins  15713695
# 141       WR   17.6    19.2     22.0     10          Julio Jones  15713701
# 142       WR   16.8    18.8     21.9      8         Stefon Diggs  15713699
# 146       WR   13.1    17.0     21.7      5           DK Metcalf  15713697
# 147       WR   14.2    17.0     19.1     11          Tyreek Hill  15713703
# 252       TE   15.1    17.2     19.7      9         Travis Kelce  15713993
#
#      Salary TeamAbbrev Away Home
# 0      8100         KC  CAR   KC
# 1      7600        SEA  SEA  BUF
# 2      7800        ARI  MIA  ARI
# 3      7100        HOU  HOU  JAX
# 47     8500        CAR  CAR   KC
# 48     8200        MIN  DET  MIN
# 49     7900        TEN  CHI  TEN
# 139    8200        ARI  MIA  ARI
# 141    7200        ATL  DEN  ATL
# 142    7400        BUF  SEA  BUF
# 146    7800        SEA  SEA  BUF
# 147    7100         KC  CAR   KC
# 252    7200         KC  CAR   KC

# %% [markdown]
# ## print N largest projections

# %%
def Nmaxelements(list1, N): 
    points = [] 
    list1 = list(list1)
    for i in range(0, N):  
        max1 = 0
        for p in list1:
            if p > max1:
                max1 = p
    
        list1.remove(max1)
        points.append(max1)
        
    return points
    
Nmaxelements(sal_proj["Ceiling"], 1)
# Out:
# [29.7]

# %% [markdown]
# ## Add position constraints
# I want the 9 highest scores, but now there has to be exactly 1 QB, 2 RB, 3 WR, 1 TE, 1 flex, and 1 Def

# %%
def Nmaxelements_pos(df):
    points = []
    total_players = 0
    total_QB = 0
    total_WR = 0
    total_RB = 0
    total_TE = 0
    total_Def = 0
    salary = 0
    qbs = df[df["Position"] == "QB"]
    rbs = df[df["Position"] == "RB"]
    wrs = df[df["Position"] == "WR"]
    te = df[df["Position"] == "TE"]
    dst = df[df["Position"] == "D/ST"]
    
    max1 = 0
    while total_QB < 1:
        for p in qbs["Ceiling"]:
            if p > max1:
                max1 = p
                total_QB += 1
    
                
                
        while total_RB < 3:
            Nmaxelements(rbs["Ceiling"], 3)
            total_RB += 1 
        print(df.loc[df['Ceiling'] == Nmaxelements(rbs["Ceiling"], 3)[0], "Name"].iloc[0])
        print(df.loc[df['Ceiling'] == Nmaxelements(rbs["Ceiling"], 3)[1], "Name"].iloc[0])
        print(df.loc[df['Ceiling'] == Nmaxelements(rbs["Ceiling"], 3)[2], "Name"].iloc[0])
    
    print(qbs.loc[qbs['Ceiling'] == max1, "Name"].iloc[0])
                            
Nmaxelements_pos(sal_proj)
# Out:
# Christian McCaffrey
# Dalvin Cook
# Derrick Henry
# Patrick Mahomes

# %% [markdown]
# # Defense data

# %%
projections = load_projections(qbFile, rbFile, wrFile, teFile, dFile)
salaries = load_DK(dkFile)
a = salaries[salaries.Position=="DST"]["Name"]
b = projections[projections.Position=="D/ST"]["Player"]

# Get nickname from projections
blist = []
for i in b:
    c = i.strip() # remove whitespace
    c = c.split()
    blist.append(c[-1])

# add nickname to projections
proj = projections.loc[projections.Position=="D/ST"].copy()
proj["Nickname"] = blist


# data frame: salaries for D/ST
salariesD = salaries.loc[salaries.Position=="DST"].copy()

# Remove whitespace from salaries' names
alist = []
for i in a:
    stripped = i.strip()
    alist.append(stripped)

# Add name back to salaries
salariesD["StripName"] = alist


# Change WAS Football Team
proj.loc[proj["Nickname"] == 'Team', "Nickname"] = "Washington"
salariesD.loc[salariesD["StripName"] == "WAS Football Team", "StripName"] = "Washington"

# Merge on StripName and Nickname (salariesD, proj)
sal_proj_D = pd.merge(salariesD, proj, how = "left", left_on="StripName", right_on="Nickname")

# Add index column
x = range(1000, len(sal_proj_D)+1000)
sal_proj_D["Index"] = x

# Remove unnecessary columns and re-order
sal_proj_D.drop(["Position_x", "StripName", "Player", "Team", "Nickname"], axis=1, inplace=True)
sal_proj_D = sal_proj_D[["Position_y", "Floor", "Median", "Ceiling", "Index", "Name", "ID", "Salary", "TeamAbbrev",
                       "Away", "Home"]]
sal_proj_D.rename(columns={'Position_y':'Position'}, inplace=True)

print(sal_proj_D)
# Out:
#    Position  Floor  Median  Ceiling  Index                Name        ID  \
# 0      D/ST    6.9     8.9     10.6   1000           Steelers   15714181
# 1      D/ST    5.7     6.2      7.7   1001             Chiefs   15714182
# 2      D/ST    5.3     6.2      7.0   1002             Ravens   15714183
# 3      D/ST    6.4     7.3      9.2   1003  WAS Football Team   15714184
# 4      D/ST    6.4     6.5      7.4   1004              Colts   15714185
# 5      D/ST    4.0     6.1      9.8   1005              Bears   15714186
# 6      D/ST    6.0     6.5      7.8   1006             Texans   15714187
# 7      D/ST    5.2     5.4      6.2   1007           Chargers   15714188
# 8      D/ST    6.2     5.8      7.2   1008             Titans   15714189
# 9      D/ST    6.3     6.3      6.9   1009          Cardinals   15714190
# 10     D/ST    5.3     6.1      6.7   1010           Seahawks   15714191
# 11     D/ST    4.4     6.2      7.4   1011           Dolphins   15714192
# 12     D/ST    4.8     5.9      7.0   1012            Broncos   15714194
# 13     D/ST    5.5     6.3      7.6   1013             Giants   15714193
# 14     D/ST    5.1     5.7      6.7   1014            Raiders   15714195
# 15     D/ST    5.9     7.5     15.3   1015            Falcons   15714196
# 16     D/ST    5.9     6.2      6.9   1016            Jaguars   15714197
# 17     D/ST    4.9     6.5      7.4   1017              Bills   15714199
# 18     D/ST    5.8     6.2      7.7   1018            Vikings   15714198
# 19     D/ST    5.1     5.8      6.4   1019              Lions   15714200
# 20     D/ST    2.7     4.7      5.8   1020           Panthers   15714201
# 21     D/ST    4.2     5.3      6.1   1021            Cowboys   15714202
#
#     Salary TeamAbbrev Away Home
# 0     4900        PIT  PIT  DAL
# 1     3700         KC  CAR   KC
# 2     3500        BAL  BAL  IND
# 3     3400        WAS  NYG  WAS
# 4     3300        IND  BAL  IND
# 5     3200        CHI  CHI  TEN
# 6     3100        HOU  HOU  JAX
# 7     3000        LAC   LV  LAC
# 8     3000        TEN  CHI  TEN
# 9     2900        ARI  MIA  ARI
# 10    2800        SEA  SEA  BUF
# 11    2800        MIA  MIA  ARI
# 12    2700        DEN  DEN  ATL
# 13    2700        NYG  NYG  WAS
# 14    2600         LV   LV  LAC
# 15    2500        ATL  DEN  ATL
# 16    2500        JAX  HOU  JAX
# 17    2400        BUF  SEA  BUF
# 18    2400        MIN  DET  MIN
# 19    2300        DET  DET  MIN
# 20    2100        CAR  CAR   KC
# 21    2000        DAL  PIT  DAL

# %% [markdown]
# ## Run program

# %%
# Load DK Salaries and Fantasy Pros projections
salaries = load_DK(dkFile)
projections = load_projections(qbFile, rbFile, wrFile, teFile, dFile)

# Store player names from DK and FP in separate vectors
names_DK = salaries["Name"]
names_FP = projections["Player"]

# Run name match function to assign index to players
df_Names = name_match(names_DK, names_FP)

# Merge names with salary data frame
salaries = pd.merge(salaries, df_Names, left_on="Name" , right_on="DK Name")
salaries.drop(['DK Name', 'FP Name'], axis=1, inplace=True)

# Merge names with projections data frame
projections = pd.merge(projections, df_Names, left_on="Player", right_on="FP Name")
projections.drop(['DK Name', 'FP Name'], axis=1, inplace=True)

# Merge salaries and projections on the new "index" value
sal_proj = pd.merge(projections, salaries, on = ["Index", "Position"])
sal_proj = sal_proj.drop_duplicates(subset=['ID']) # Removes all those Chris Thompson's

# Getting rid of duplicate columns, keeping Draftkings columns "Name" and "TeamAbbrev"
sal_proj.drop(['Player', 'Team'], axis=1, inplace=True)

# Add defense to end of data frame
sal_proj  = sal_proj.append(sal_proj_D)

# Drop low projected players
sal_proj = sal_proj[sal_proj['Median'] >= 5]

print(sal_proj.head(5))
# Out:
#   Position  Floor  Median  Ceiling  Index             Name        ID  Salary  \
# 0       QB   21.2    23.7     29.7      3  Patrick Mahomes  15713425    8100
# 1       QB   20.1    23.2     29.6      7   Russell Wilson  15713427    7600
# 2       QB   21.6    23.2     28.9      6     Kyler Murray  15713426    7800
# 3       QB   20.4    22.2     25.6     12   Deshaun Watson  15713428    7100
# 4       QB   20.8    22.1     25.8     14       Josh Allen  15713429    7000
#
#   TeamAbbrev Away Home
# 0         KC  CAR   KC
# 1        SEA  SEA  BUF
# 2        ARI  MIA  ARI
# 3        HOU  HOU  JAX
# 4        BUF  SEA  BUF

# %% [markdown]
# # Write to .csv

# %%
sal_proj.to_csv(r'C:\Users\punco\OneDrive\Desktop\Fantasy Football\Week 9.csv', index = False)

# %% [markdown]
# From here, I can use excel solver to produce 1 optimal lineup with Draft Kings constraints, or I could write a program in Python that produces the n most optimal lineups.

# %% [markdown]
# ## Experimenting with stacking (matching QB with 1 or 2 pass catchers or RB, bring back with 1 or 2 players from other team)

# %% [markdown]
# for every qb
#     find numToPair players from same team
#     return dataframe: "QB" | QBPoints | QBSalary | "Player1" | Player1Points | Player1Salary | ... TotalSalary | TotalPts

# %%
for q in sal_proj[sal_proj.Position=="QB"].itertuples():
    print(q)
# Out:
# Pandas(Index=0, Position='QB', Floor=21.2, Median=23.7, Ceiling=29.7, _5=3, Name='Patrick Mahomes', ID=15713425, Salary=8100, TeamAbbrev='KC', Away='CAR', Home='KC')
# Pandas(Index=1, Position='QB', Floor=20.1, Median=23.2, Ceiling=29.6, _5=7, Name='Russell Wilson', ID=15713427, Salary=7600, TeamAbbrev='SEA', Away='SEA', Home='BUF')
# Pandas(Index=2, Position='QB', Floor=21.6, Median=23.2, Ceiling=28.9, _5=6, Name='Kyler Murray', ID=15713426, Salary=7800, TeamAbbrev='ARI', Away='MIA', Home='ARI')
# Pandas(Index=3, Position='QB', Floor=20.4, Median=22.2, Ceiling=25.6, _5=12, Name='Deshaun Watson', ID=15713428, Salary=7100, TeamAbbrev='HOU', Away='HOU', Home='JAX')
# Pandas(Index=4, Position='QB', Floor=20.8, Median=22.1, Ceiling=25.8, _5=14, Name='Josh Allen', ID=15713429, Salary=7000, TeamAbbrev='BUF', Away='SEA', Home='BUF')
# Pandas(Index=5, Position='QB', Floor=20.9, Median=22.0, Ceiling=28.7, _5=20, Name='Justin Herbert', ID=15713431, Salary=6800, TeamAbbrev='LAC', Away='LV', Home='LAC')
# Pandas(Index=6, Position='QB', Floor=18.8, Median=20.0, Ceiling=26.9, _5=17, Name='Lamar Jackson', ID=15713430, Salary=6900, TeamAbbrev='BAL', Away='BAL', Home='IND')
# Pandas(Index=7, Position='QB', Floor=16.7, Median=18.4, Ceiling=22.2, _5=30, Name='Ben Roethlisberger', ID=15713433, Salary=6500, TeamAbbrev='PIT', Away='PIT', Home='DAL')
# Pandas(Index=8, Position='QB', Floor=17.9, Median=18.4, Ceiling=22.0, _5=31, Name='Matt Ryan', ID=15713434, Salary=6400, TeamAbbrev='ATL', Away='DEN', Home='ATL')
# Pandas(Index=9, Position='QB', Floor=16.6, Median=18.0, Ceiling=23.2, _5=26, Name='Matthew Stafford', ID=15713432, Salary=6600, TeamAbbrev='DET', Away='DET', Home='MIN')
# Pandas(Index=10, Position='QB', Floor=17.2, Median=17.8, Ceiling=23.0, _5=46, Name='Derek Carr', ID=15713439, Salary=5700, TeamAbbrev='LV', Away='LV', Home='LAC')
# Pandas(Index=11, Position='QB', Floor=16.0, Median=17.6, Ceiling=21.7, _5=34, Name='Ryan Tannehill', ID=15713435, Salary=6300, TeamAbbrev='TEN', Away='CHI', Home='TEN')
# Pandas(Index=12, Position='QB', Floor=15.4, Median=16.7, Ceiling=22.9, _5=40, Name='Teddy Bridgewater', ID=15713437, Salary=6000, TeamAbbrev='CAR', Away='CAR', Home='KC')
# Pandas(Index=13, Position='QB', Floor=15.0, Median=16.6, Ceiling=21.7, _5=36, Name='Kirk Cousins', ID=15713436, Salary=6200, TeamAbbrev='MIN', Away='DET', Home='MIN')
# Pandas(Index=14, Position='QB', Floor=15.0, Median=15.6, Ceiling=22.9, _5=56, Name='Daniel Jones', ID=15713443, Salary=5400, TeamAbbrev='NYG', Away='NYG', Home='WAS')
# Pandas(Index=15, Position='QB', Floor=15.1, Median=15.0, Ceiling=17.1, _5=61, Name='Drew Lock', ID=15713446, Salary=5200, TeamAbbrev='DEN', Away='DEN', Home='ATL')
# Pandas(Index=16, Position='QB', Floor=13.8, Median=14.9, Ceiling=17.3, _5=54, Name='Nick Foles', ID=15713442, Salary=5500, TeamAbbrev='CHI', Away='CHI', Home='TEN')
# Pandas(Index=17, Position='QB', Floor=13.5, Median=14.9, Ceiling=20.9, _5=49, Name='Philip Rivers', ID=15713440, Salary=5600, TeamAbbrev='IND', Away='BAL', Home='IND')
# Pandas(Index=18, Position='QB', Floor=14.1, Median=14.4, Ceiling=17.4, _5=59, Name='Kyle Allen', ID=15713444, Salary=5300, TeamAbbrev='WAS', Away='NYG', Home='WAS')
# Pandas(Index=19, Position='QB', Floor=13.8, Median=13.9, Ceiling=16.4, _5=52, Name='Tua Tagovailoa', ID=15713441, Salary=5500, TeamAbbrev='MIA', Away='MIA', Home='ARI')
# Pandas(Index=20, Position='QB', Floor=13.9, Median=13.8, Ceiling=16.8, _5=80, Name='Jake Luton', ID=15713450, Salary=4900, TeamAbbrev='JAX', Away='HOU', Home='JAX')
# Pandas(Index=21, Position='QB', Floor=5.9, Median=9.9, Ceiling=15.5, _5=89, Name='Garrett Gilbert', ID=15713454, Salary=4800, TeamAbbrev='DAL', Away='PIT', Home='DAL')
# Pandas(Index=22, Position='QB', Floor=0.8, Median=6.6, Ceiling=18.5, _5=70, Name='Ryan Fitzpatrick', ID=15713447, Salary=5000, TeamAbbrev='MIA', Away='MIA', Home='ARI')
# Pandas(Index=23, Position='QB', Floor=3.4, Median=6.0, Ceiling=6.4, _5=90, Name='Cooper Rush', ID=15734118, Salary=4800, TeamAbbrev='DAL', Away='PIT', Home='DAL')

# %%
def stack_DF(df, rb=False):
    qb_df = df[df.Position=="QB"] # QB only data frame with QB only
    crit1 = df["Position"] !="QB"
    crit2 = df["Position"] !="D/ST"
    crit3 = df["Position"] !="RB"
    if(rb)==True:
        others_df = df[crit1 & crit2] # data frame with RB, WR, TE only
    else:
        others_df = df[crit1 & crit2 & crit3] # Data frame with WR, TE only
    
    playerList = []
    
    for q in qb_df.itertuples(): # iterate over qbs
        playerList.append(q) # add to new list
        for o in others_df.itertuples(): # iterate over non-qbs
            if(q[9]==o[9]): # add to new list if on same team as qb
                playerList.append(o)
    
    playerDF = pd.DataFrame(playerList)
    return(playerDF)

stackedDF = stack_DF(sal_proj)
print(stackedDF)
# Out:
#      Index Position  Floor  Median  Ceiling   _5                   Name  \
# 0        0       QB   21.2    23.7     29.7    3        Patrick Mahomes
# 1      147       WR   14.2    17.0     19.1   11            Tyreek Hill
# 2      182       WR    7.8     9.2     10.4   82         Mecole Hardman
# 3      194       WR    4.5     6.4      7.4  209      Demarcus Robinson
# 4      252       TE   15.1    17.2     19.7    9           Travis Kelce
# 5        1       QB   20.1    23.2     29.6    7         Russell Wilson
# 6      143       WR   16.5    18.3     21.0   21          Tyler Lockett
# 7      146       WR   13.1    17.0     21.7    5             DK Metcalf
# 8      191       WR    5.4     7.0      8.6  218            David Moore
# 9      267       TE    6.0     6.5      7.5  219             Greg Olsen
# 10       2       QB   21.6    23.2     28.9    6           Kyler Murray
# 11     139       WR   18.4    20.3     23.9    1        DeAndre Hopkins
# 12     161       WR    8.4    12.3     16.9   58         Christian Kirk
# 13     189       WR    6.4     7.6      8.4  197       Larry Fitzgerald
# 14     199       WR    3.4     5.8      9.8  213          Andy Isabella
# 15       3       QB   20.4    22.2     25.6   12         Deshaun Watson
# 16     151       WR   11.8    15.0     19.1   23          Will Fuller V
# 17     158       WR    9.8    13.5     17.4   53          Brandin Cooks
# 18     184       WR    7.4     9.1     10.3  101           Randall Cobb
# 19     205       WR    4.1     5.3      6.1  252           Kenny Stills
# 20     269       TE    5.6     6.4      7.2  207           Jordan Akins
# 21     274       TE    4.3     5.3      7.0  114           Darren Fells
# 22       4       QB   20.8    22.1     25.8   14             Josh Allen
# 23     142       WR   16.8    18.8     21.9    8           Stefon Diggs
# 24     167       WR    9.3    11.6     16.9   95             John Brown
# 25     170       WR    8.8    11.3     12.9   55           Cole Beasley
# 26       5       QB   20.9    22.0     28.7   20         Justin Herbert
# 27     140       WR   18.6    20.2     22.9   13           Keenan Allen
# 28     157       WR   11.1    13.5     16.2   65          Mike Williams
# 29     196       WR    5.0     6.0      7.3  217           Jalen Guyton
# 30     257       TE    8.2    11.4     15.1  131           Hunter Henry
# 31       6       QB   18.8    20.0     26.9   17          Lamar Jackson
# 32     165       WR    9.6    11.9     12.9   42         Marquise Brown
# 33     202       WR    4.6     5.4      6.0  214           Miles Boykin
# 34     203       WR    3.8     5.3      6.4  121        Willie Snead IV
# 35     255       TE   10.4    12.0     15.7   85           Mark Andrews
# 36       7       QB   16.7    18.4     22.2   30     Ben Roethlisberger
# 37     156       WR   11.5    13.5     18.1   37    JuJu Smith-Schuster
# 38     160       WR    7.6    12.7     16.9   48         Chase Claypool
# 39     163       WR   10.2    12.0     13.7   73        Diontae Johnson
# 40     201       WR    3.0     5.5      7.3  268       James Washington
# 41     261       TE    8.3     9.8     11.4  102             Eric Ebron
# 42       8       QB   17.9    18.4     22.0   31              Matt Ryan
# 43     141       WR   17.6    19.2     22.0   10            Julio Jones
# 44     168       WR    9.7    11.4     17.8   15          Calvin Ridley
# 45     178       WR    8.2     9.7     10.6  100           Russell Gage
# 46     200       WR    3.2     5.7     12.0  238      Olamide Zaccheaus
# 47     258       TE    8.3    10.2     11.5  118           Hayden Hurst
# 48       9       QB   16.6    18.0     23.2   26       Matthew Stafford
# 49     154       WR   11.6    13.8     17.8   67       Marvin Jones Jr.
# 50     175       WR    9.1    10.6     11.7  200         Danny Amendola
# 51     197       WR    2.3     6.0      8.5  198            Marvin Hall
# 52     254       TE   12.1    13.0     16.1   68         T.J. Hockenson
# 53      10       QB   17.2    17.8     23.0   46             Derek Carr
# 54     174       WR    9.3    10.8     16.7   75        Henry Ruggs III
# 55     179       WR    7.8     9.6     10.5  116         Hunter Renfrow
# 56     188       WR    6.2     8.0      9.8   91         Nelson Agholor
# 57     253       TE   14.6    16.3     19.7   44          Darren Waller
# 58      11       QB   16.0    17.6     21.7   34         Ryan Tannehill
# 59     152       WR   11.8    14.9     18.6   27             A.J. Brown
# 60     166       WR    9.3    11.7     13.5   43            Corey Davis
# 61     204       WR    4.1     5.3      6.4  265          Kalif Raymond
# 62     260       TE    8.1     9.9     12.5  196            Jonnu Smith
# 63     270       TE    5.4     6.0      6.9  278        Anthony Firkser
# 64      12       QB   15.4    16.7     22.9   40      Teddy Bridgewater
# 65     149       WR   14.6    16.0     20.6   33         Robby Anderson
# 66     181       WR    6.1     9.3     10.6  104          Curtis Samuel
# 67      13       QB   15.0    16.6     21.7   36           Kirk Cousins
# 68     144       WR   15.8    17.3     19.9   25           Adam Thielen
# 69     150       WR   13.8    15.8     18.9   39       Justin Jefferson
# 70     271       TE    4.1     5.6      6.8  275          Irv Smith Jr.
# 71     275       TE    3.9     5.0      5.4  220           Kyle Rudolph
# 72      14       QB   15.0    15.6     22.9   56           Daniel Jones
# 73     159       WR   11.6    13.0     18.4   72         Darius Slayton
# 74     162       WR   11.5    12.1     13.4   87       Sterling Shepard
# 75     259       TE    9.2     9.9     11.0  110            Evan Engram
# 76      15       QB   15.1    15.0     17.1   61              Drew Lock
# 77     164       WR   10.2    11.9     15.4   93            Jerry Jeudy
# 78     171       WR    9.6    11.1     15.2   76            Tim Patrick
# 79     195       WR    4.2     6.4      7.5  206              KJ Hamler
# 80     256       TE   10.6    11.9     14.8   97              Noah Fant
# 81     268       TE    5.3     6.4      7.9  277     Albert Okwuegbunam
# 82      16       QB   13.8    14.9     17.3   54             Nick Foles
# 83      81       WR    3.7     5.6      7.0  215  Cordarrelle Patterson
# 84     148       WR   15.8    17.0     20.4   18      Allen Robinson II
# 85     176       WR    8.5    10.1     11.1  195         Darnell Mooney
# 86     180       WR    8.8     9.4     10.1  185         Anthony Miller
# 87     262       TE    7.6     8.9      9.8  199           Jimmy Graham
# 88      17       QB   13.5    14.9     20.9   49          Philip Rivers
# 89     177       WR    9.0     9.9     11.2  108            Zach Pascal
# 90     185       WR   12.3     8.8     12.3   98            T.Y. Hilton
# 91     187       WR    7.4     8.1      9.6  194    Michael Pittman Jr.
# 92     192       WR    4.3     6.5      7.7  247         Marcus Johnson
# 93     264       TE    7.3     8.5     13.9  204            Trey Burton
# 94     273       TE    4.1     5.5      7.4  273             Jack Doyle
# 95      18       QB   14.1    14.4     17.4   59             Kyle Allen
# 96     145       WR   15.5    17.2     20.5   29         Terry McLaurin
# 97     190       WR    8.5     7.1      8.5  208        Dontrelle Inman
# 98     198       WR    4.3     5.9      6.8  259          Isaiah Wright
# 99     265       TE    7.1     8.3      9.8  201           Logan Thomas
# 100     19       QB   13.8    13.9     16.4   52         Tua Tagovailoa
# 101    153       WR   11.6    13.8     16.5   63         DeVante Parker
# 102    183       WR    7.5     9.1     11.0  119       Preston Williams
# 103    193       WR    5.1     6.4      8.2  243           Jakeem Grant
# 104    207       WR    5.3     5.1      5.3  240            Isaiah Ford
# 105    263       TE    8.0     8.8     10.6  105           Mike Gesicki
# 106     20       QB   13.9    13.8     16.8   80             Jake Luton
# 107    169       WR   10.5    11.4     11.7   64           DJ Chark Jr.
# 108    172       WR   10.0    10.8     12.2  113   Laviska Shenault Jr.
# 109    206       WR    4.7     5.3      6.3  250           Chris Conley
# 110    272       TE    4.4     5.6      6.6  280           Tyler Eifert
# 111     21       QB    5.9     9.9     15.5   89        Garrett Gilbert
# 112    155       WR   11.7    13.7     17.6   51           Amari Cooper
# 113    173       WR    8.9    10.8     12.0   81            CeeDee Lamb
# 114    186       WR    6.9     8.4      9.2  193         Michael Gallup
# 115    266       TE    6.6     7.4      8.0  202         Dalton Schultz
# 116     22       QB    0.8     6.6     18.5   70       Ryan Fitzpatrick
# 117    153       WR   11.6    13.8     16.5   63         DeVante Parker
# 118    183       WR    7.5     9.1     11.0  119       Preston Williams
# 119    193       WR    5.1     6.4      8.2  243           Jakeem Grant
# 120    207       WR    5.3     5.1      5.3  240            Isaiah Ford
# 121    263       TE    8.0     8.8     10.6  105           Mike Gesicki
# 122     23       QB    3.4     6.0      6.4   90            Cooper Rush
# 123    155       WR   11.7    13.7     17.6   51           Amari Cooper
# 124    173       WR    8.9    10.8     12.0   81            CeeDee Lamb
# 125    186       WR    6.9     8.4      9.2  193         Michael Gallup
# 126    266       TE    6.6     7.4      8.0  202         Dalton Schultz
#
#            ID  Salary TeamAbbrev Away Home
# 0    15713425    8100         KC  CAR   KC
# 1    15713703    7100         KC  CAR   KC
# 2    15713763    4800         KC  CAR   KC
# 3    15713821    3200         KC  CAR   KC
# 4    15713993    7200         KC  CAR   KC
# 5    15713427    7600        SEA  SEA  BUF
# 6    15713711    6800        SEA  SEA  BUF
# 7    15713697    7800        SEA  SEA  BUF
# 8    15713833    3100        SEA  SEA  BUF
# 9    15714031    3100        SEA  SEA  BUF
# 10   15713426    7800        ARI  MIA  ARI
# 11   15713695    8200        ARI  MIA  ARI
# 12   15713743    5300        ARI  MIA  ARI
# 13   15713803    3800        ARI  MIA  ARI
# 14   15713823    3200        ARI  MIA  ARI
# 15   15713428    7100        HOU  HOU  JAX
# 16   15713713    6800        HOU  HOU  JAX
# 17   15713739    5500        HOU  HOU  JAX
# 18   15713777    4500        HOU  HOU  JAX
# 19   15713901    3000        HOU  HOU  JAX
# 20   15714027    3300        HOU  HOU  JAX
# 21   15714009    4200        HOU  HOU  JAX
# 22   15713429    7000        BUF  SEA  BUF
# 23   15713699    7400        BUF  SEA  BUF
# 24   15713775    4600        BUF  SEA  BUF
# 25   15713741    5400        BUF  SEA  BUF
# 26   15713431    6800        LAC   LV  LAC
# 27   15713707    7000        LAC   LV  LAC
# 28   15713751    5100        LAC   LV  LAC
# 29   15713835    3100        LAC   LV  LAC
# 30   15714013    4000        LAC   LV  LAC
# 31   15713430    6900        BAL  BAL  IND
# 32   15713729    6000        BAL  BAL  IND
# 33   15713829    3200        BAL  BAL  IND
# 34   15713791    4100        BAL  BAL  IND
# 35   15713999    4800        BAL  BAL  IND
# 36   15713433    6500        PIT  PIT  DAL
# 37   15713725    6200        PIT  PIT  DAL
# 38   15713733    5700        PIT  PIT  DAL
# 39   15713755    5000        PIT  PIT  DAL
# 40   15713839    3000        PIT  PIT  DAL
# 41   15714003    4500        PIT  PIT  DAL
# 42   15713434    6400        ATL  DEN  ATL
# 43   15713701    7200        ATL  DEN  ATL
# 44   15713705    7000        ATL  DEN  ATL
# 45   15713779    4500        ATL  DEN  ATL
# 46   15713947    3000        ATL  DEN  ATL
# 47   15714011    4100        ATL  DEN  ATL
# 48   15713432    6600        DET  DET  MIN
# 49   15713749    5100        DET  DET  MIN
# 50   15713809    3700        DET  DET  MIN
# 51   15713805    3800        DET  DET  MIN
# 52   15713997    5100        DET  DET  MIN
# 53   15713439    5700         LV   LV  LAC
# 54   15713761    4900         LV   LV  LAC
# 55   15713789    4100         LV   LV  LAC
# 56   15713769    4700         LV   LV  LAC
# 57   15713995    5800         LV   LV  LAC
# 58   15713435    6300        TEN  CHI  TEN
# 59   15713717    6600        TEN  CHI  TEN
# 60   15713731    5900        TEN  CHI  TEN
# 61   15713849    3000        TEN  CHI  TEN
# 62   15714015    3900        TEN  CHI  TEN
# 63   15714049    2800        TEN  CHI  TEN
# 64   15713437    6000        CAR  CAR   KC
# 65   15713723    6300        CAR  CAR   KC
# 66   15713781    4400        CAR  CAR   KC
# 67   15713436    6200        MIN  DET  MIN
# 68   15713715    6700        MIN  DET  MIN
# 69   15713727    6100        MIN  DET  MIN
# 70   15714041    2900        MIN  DET  MIN
# 71   15714033    3100        MIN  DET  MIN
# 72   15713443    5400        NYG  NYG  WAS
# 73   15713753    5000        NYG  NYG  WAS
# 74   15713765    4800        NYG  NYG  WAS
# 75   15714007    4300        NYG  NYG  WAS
# 76   15713446    5200        DEN  DEN  ATL
# 77   15713767    4700        DEN  DEN  ATL
# 78   15713759    4900        DEN  DEN  ATL
# 79   15713815    3400        DEN  DEN  ATL
# 80   15714001    4600        DEN  DEN  ATL
# 81   15714047    2800        DEN  DEN  ATL
# 82   15713442    5500        CHI  CHI  TEN
# 83   15713825    3200        CHI  CHI  TEN
# 84   15713709    6900        CHI  CHI  TEN
# 85   15713801    3900        CHI  CHI  TEN
# 86   15713795    4000        CHI  CHI  TEN
# 87   15714017    3800        CHI  CHI  TEN
# 88   15713440    5600        IND  BAL  IND
# 89   15713783    4300        IND  BAL  IND
# 90   15713773    4600        IND  BAL  IND
# 91   15713799    3900        IND  BAL  IND
# 92   15713919    3000        IND  BAL  IND
# 93   15714023    3500        IND  BAL  IND
# 94   15714037    2900        IND  BAL  IND
# 95   15713444    5300        WAS  NYG  WAS
# 96   15713719    6500        WAS  NYG  WAS
# 97   15713819    3300        WAS  NYG  WAS
# 98   15713859    3000        WAS  NYG  WAS
# 99   15714019    3700        WAS  NYG  WAS
# 100  15713441    5500        MIA  MIA  ARI
# 101  15713745    5200        MIA  MIA  ARI
# 102  15713787    4100        MIA  MIA  ARI
# 103  15713931    3000        MIA  MIA  ARI
# 104  15713837    3000        MIA  MIA  ARI
# 105  15714005    4400        MIA  MIA  ARI
# 106  15713450    4900        JAX  HOU  JAX
# 107  15713747    5200        JAX  HOU  JAX
# 108  15713785    4200        JAX  HOU  JAX
# 109  15713895    3000        JAX  HOU  JAX
# 110  15714051    2700        JAX  HOU  JAX
# 111  15713454    4800        DAL  PIT  DAL
# 112  15713735    5600        DAL  PIT  DAL
# 113  15713757    4900        DAL  PIT  DAL
# 114  15713797    4000        DAL  PIT  DAL
# 115  15714021    3600        DAL  PIT  DAL
# 116  15713447    5000        MIA  MIA  ARI
# 117  15713745    5200        MIA  MIA  ARI
# 118  15713787    4100        MIA  MIA  ARI
# 119  15713931    3000        MIA  MIA  ARI
# 120  15713837    3000        MIA  MIA  ARI
# 121  15714005    4400        MIA  MIA  ARI
# 122  15734118    4800        DAL  PIT  DAL
# 123  15713735    5600        DAL  PIT  DAL
# 124  15713757    4900        DAL  PIT  DAL
# 125  15713797    4000        DAL  PIT  DAL
# 126  15714021    3600        DAL  PIT  DAL
